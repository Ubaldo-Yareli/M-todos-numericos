# %% [markdown]
# <a href="https://colab.research.google.com/github/Ubaldo-Yareli/M-todos-numericos/blob/main/Introduccion/graficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Función cuadrática.
def f(x):
    return x
def g(x):
    return -3**(-x)
def h(x):
    return x-3**(-x)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
#Graficar ambas funciones.
plt.figure(figsize=(7, 7))
plt.plot(x, f(x))
plt.plot(x, g(x))
plt.plot(x, h(x))
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.xlim(-10, 10)
plt.ylim(-5, 5)
plt.grid()
plt.savefig("output.png") # Guardar gráfico como imágen PNG.
#Mostrarlo.
plt.title('Gráfica')
plt.xlabel('eje y')
plt.ylabel('eje x')
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.

# %% [markdown]
# En la Gráfica, se pueden apreciar qué la función h(x) es una suma de las funciones f(x)+g(x), mostrando el eje de la x y el eje de las y
